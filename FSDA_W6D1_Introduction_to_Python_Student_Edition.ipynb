# %% [markdown]
# <a href="https://colab.research.google.com/github/mviganalk/learn_python/blob/main/FSDA_W6D1_Introduction_to_Python_Student_Edition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Case Study 1: Saldo Deposito**
#
# Dalam Case Study ini kita akan membuat kode Python untuk menghitung saldo deposito setelah dikenakan bunga dan pajak.
#
# Di Case Study ini kita akan menggunakan konsep:
# - Variable
# - Control flow
# - Python function
# - List & Dictionary
# - Pandas DataFrame

# %% [markdown]
# # Day 1
# # Introduction to Python
#
# Hari ini kita akan melihat konsep dasar Python, yakni:
# - Variabel
# - Data types
# - Control flow
#
# Di akhir kita akan menggunakan semua konsep di atas untuk menghitung saldo deposito setelah pajak.

# %% [markdown]
# ## A. Variable
#
# Variable is a place to store data. Imagine it’s like a basket for your data.
#
# ![gambar.png](data:image/png;base64,...)

# %% [markdown]
# Untuk membuat variabel:
#
# ```python
# nama_variabel = ...
# ```
#
# Sebagai contoh, di suatu bank mungkin terdapat variabel nama, umur, dan saldo rekening.

# %%
nama = 'Akmal'
umur = 18
Saldo_Rekening = 169.8

# %% [markdown]
# Cek hasilnya dengan menggunakan `print(nama_variabel)`

# %%
print(nama)
# Out:
# Akmal

# %%
print(umur)
# Out:
# 18

# %%
print(Saldo_Rekening)
# Out:
# 169.8

# %% [markdown]
# ### Penamaan Variabel
# Untuk memberi nama variabel, terdapat beberapa aturan:
# - Can not start variable name with a number
# - Variable name can only contains A-Z, 0-9, and underscore (_)
#
# Diantara tiga variabel di bawah ini, mana penamaan variabel yang tepat?

# %%
nama = "Syafira"

# %%
Saldo_Rekening1 = 187.9

# %%
umur = 23

# %% [markdown]
# ### 💀 Beware 💀: Case Sensitivity
#
# Hati-hati: penulisan variabel di Python case sensitive: huruf besar dan huruf kecil berpengaruh!

# %%
Saldo_Rekening
# Out:
# 169.8

# %%
saldo_rekening
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-da28e0e942b1> in <cell line: 1>()
# ----> 1 saldo_rekening
#
# NameError: name 'saldo_rekening' is not defined

# %% [markdown]
# ### Manipulasi Variabel
#
# Kamu bisa menggunakan variabel yang sudah ada untuk membuat variabel yang baru, contohnya
#
# **Contoh 1**

# %%
# Cek nilai Tinggi_Badan sebelumnya
print(Saldo_Rekening)
# Out:
# 169.8

# %%
# Sekarang kita kurangi Tinggi_Badan senilai 2 dolar
Saldo_Rekening = Saldo_Rekening - 2

# Lalu kita cek nilai Tinggi_Badan sekarang
print(Saldo_Rekening)
# Out:
# 167.8

# %% [markdown]
# **Contoh 2**

# %%
avg_balance = (Saldo_Rekening + Saldo_Rekening1)/2
print(avg_balance)
# Out:
# 177.85000000000002

# %% [markdown]
# ## B. Data Types
#
# Di Python, terdapat banyak jenis data yang bisa di-assign ke variabel.
#
# Untuk mengecek tipe data dari variabel, kita bisa menggunakan `type(nama_variabel)`

# %%
# Let's check the type of these variables
balance = 3
balance1 = 3.55
new_customer = ' Syafira'
new_customer_is_married = False
customers = ['Akmal', 'Brian']

# %%
type(balance)
# Out:
# int

# %%
type(balance1)
# Out:
# float

# %%
type(new_customer)
# Out:
# str

# %%
type(new_customer_is_married)
# Out:
# bool

# %%
type(customers)
# Out:
# list

# %% [markdown]
# ### String
# Tipe data teks/string bisa dibuat dengan tanda kutip 1 ('teks'), tanda kutip 2 ("teks") atau untuk banyak baris menggunakan tanda kutip 3 (''' text ''')

# %%
single_text = 'Saldo Syafira di bank 3 juta'
print(single_text)
# Out:
# Saldo Syafira di bank 3 juta

# %%
double_text = "Saldo Syafira di bank 3 juta"
print(double_text)
# Out:
# Saldo Syafira di bank 3 juta

# %%
multiline_text = '''Saldo Syafira di bank adalah
3 juta rupiah'''
print(multiline_text)
# Out:
# Saldo Syafira di bank adalah
# 3 juta rupiah

# %% [markdown]
# Kita bisa memformat text dengan menggunakan f-string, contohnya:

# %%
print(f'Saldo rekening{new_customer} adalah sebesar {balance1} juta rupiah')
# Out:
# Saldo rekening Syafira adalah sebesar 3.55 juta rupiah

# %%
print(f"Saldo rekening{new_customer} adalah sebesar {balance1} juta rupiah")
# Out:
# Saldo rekening Syafira adalah sebesar 3.55 juta rupiah

# %%
print(f'''Saldo rekening{new_customer} adalah
sebesar {balance1} juta rupiah''')
# Out:
# Saldo rekening Syafira adalah
# sebesar 3.55 juta rupiah

# %% [markdown]
# ### Sequence (List, Tuple)
#
# Apa yang terjadi kalau kita punya banyak nasabah, apakah perlu dibuat variabelnya 1 per satu?
#
# Tidak, kita bisa menyimpannya dalam sequence seperti list atau tuple

# %%
# List adalah sequence yang isinya bisa diubah-ubah
# Sebagai contoh, ini adalah list nama nasabah
nasabah = ['Akmal', 'Syafira', 'Brian']
print(nasabah)
# Out:
# ['Akmal', 'Syafira', 'Brian']

# %% [markdown]
# Untuk mengakses nilai di dalam list, kita bisa menggunakan `nama_list[indeks]`

# %%
# Mengakses nama nasabah di dalam list
# Nasabah pertama
print(nasabah[0])

# Nasabah kedua
print(nasabah[1])

# Nasabah terakhir
print(nasabah[-1])
# Out:
# Akmal
# Syafira
# Brian

# %%
# Isi list bisa diubah-ubah, misalnya:
# Akmal ganti nama jadi Chandra
# Syafira nama lengkapnya "Syafira Pratiwi"
nasabah[0] = 'Chandra'
nasabah[1] = nasabah[1] + ' Pratiwi'
print(nasabah)
# Out:
# ['Chandra', 'Syafira Pratiwi', 'Brian']

# %%
# Tuple adalah sequence yang isinya TIDAK bisa diubah-ubah
# Sebagai contoh, ini adalah tuple saldo nasabah
saldo = (125, 498, 76.25)
print(saldo)
# Out:
# (125, 498, 76.25)

# %%
# Mengakses saldo nasabah di dalam list
# Nasabah pertama
print(saldo[0])

# Nasabah kedua
print(saldo[1])

# Nasabah terakhir
print(saldo[-1])
# Out:
# 125
# 498
# 76.25

# %%
# Isi tuple TIDAK bisa diubah-ubah:
# Saldo Brian bertambah sebesar 19 dolar
saldo[-1] == (saldo[-1] + 19)
print(saldo)
# Out:
# (125, 498, 76.25)

# %% [markdown]
# ### Dictionary
#
# Untuk menyimpan relasi antara nasabah dengan saldonya, lebih baik menggunakan dictionary.
#
# Kunci dari dictionary adalah nama nasabah dan Nilai dari kunci tersebut adalah saldonya.

# %%
saldo_nasabah = {
    'Chandra' : 125,
    'Syafira' : 498,
    'Brian' : 79.25
}

# %%
# Untuk mengecek nama nasabah yang ada, gunakan kuncinya: .keys()
saldo_nasabah.keys()
# Out:
# dict_keys(['Chandra', 'Syafira', 'Brian'])

# %%
# Untuk mengecek saldo nasabah, gunakan kurung siku [] seperti list dan tuple
saldo_nasabah['Chandra']
# Out:
# 125

# %% [markdown]
# ## C. Control Flow
#
# Control flow adalah cara untuk mengatur alur dan kondisi untuk menjalankan program

# %% [markdown]
# ### IF Condition
# Jalankan program ini jika kondisinya terpenuhi

# %%
name = 'Akmal'

# If the name is Akmal, give him discount 50%;
# for Richard, the discount is 30%;
# for everyone else 25% discount
if name == 'Akmal':
  discount = 0.5
elif name == 'Richard':
  discount = 0.3
else:
  discount = 0.25

print(name, discount)
# Out:
# Akmal 0.5

# %% [markdown]
# ### FOR Condition
# Mengulangi eksekusi program

# %%
for client in nasabah:
  print(f'Welcome {client}!')
# Out:
# Welcome Chandra!
# Welcome Syafira Pratiwi!
# Welcome Brian!

# %% [markdown]
# ---
#
# # **Latihan: Saldo Deposito**
#
# Dalam Latihan ini kita akan membuat kode Python untuk menghitung saldo deposito setelah dikenakan bunga dan pajak.
#
# Di Latihan ini kita akan menggunakan konsep:
# - variable
# - control flow

# %% [markdown]
# ## **1. Konsep Dasar Bunga Sederhana**
#
# ---
#
# Menurut [Pusat Data Kontan](https://pusatdata.kontan.co.id/bungadeposito/), suku bunga deposito saat ini berkisar antara 2% hingga 5% per tahun.
#
# Sebagai contoh, apabila Brian mendepositokan Rp10.000.000,- selama 1 tahun dengan suku bunga tahunan 3,5%, maka Brian akan mendapatkan bunga sebesar Rp350.000, dihitung dengan perhitungan _bunga sederhana_ berikut
#
# $$
# \text{bunga} = 0.035 \times 10,000,000 = 350,000
# $$
#
# Sehingga setelah 1 tahun, uang Brian bertambah menjadi $\text{saldo_akhir} = 10,000,000+350,000=10,350,000$.

# %% [markdown]
# ### **Latihan 1.1 | Variabel**
# Lakukan perhitungan di atas dengan menggunakan Python.
#
# Buat dua variabel:
# - `saldo_awal`: Nilai deposito awal Brian, bernilai Rp10000000
# - `suku_bunga`: Suku bunga deposito per tahun, bernilai 3.5% atau 0.035
#
# Kemudian gunakan dua variabel itu untuk menghitung dua variabel lainnya:
# - `bunga`: Bunga yang didapat Brian setelah 1 tahun
# - `saldo_akhir`: Nilai uang Brian setelah 1 tahun
#
# Jangan lupa `print` nilai `bunga` dan `saldo_akhir`.

# %%
saldo_awal = 10000000
suku_bunga = 0.035

bunga = suku_bunga * saldo_awal
saldo_akhir = saldo_awal + bunga

print("Bunga yang didapat Brian:", bunga)
print("Saldo akhir setelah 1 tahun:", saldo_akhir)
# Out:
# Bunga yang didapat Brian: 350000.00000000006
# Saldo akhir setelah 1 tahun: 10350000.0

# %% [markdown]
# ### **Latihan 1.2 | Tipe Data**
#
# Periksa tipe data variabel `bunga` dan `saldo_akhir` dengan menggunakan fungsi `type()`. Apa tipe data dua variabel tersebut?

# %%
type(bunga)
# Out:
# float

# %%
type(saldo_akhir)
# Out:
# float

# %% [markdown]
# Di Python, data tipe `float` sering diprint dengan tidak tepat. Sebagai contoh, `print(bunga)` menghasilkan `350000.00000000006`, bukan `350000.0`. Hal ini karena komputer memiliki [keterbatasan untuk menghitung angka desimal](https://docs.python.org/3/tutorial/floatingpoint.html).
#
# Untuk mengatasi ini, kita bisa menggunakan fungsi `round(angka,2)`, contohnya:
#
# `round(bunga,2)`

# %%
round(bunga,2)
# Out:
# 350000.0

# %% [markdown]
# Jika menggunakan f-string, maka pengaturan 2 angka desimal bisa menggunakan `{angka:.2f}`, contohnya:
#
# ```
# print(f'Bunga: {bunga:.2f}')
# ```

# %%
print(f'Bunga: {bunga:.2f}')
# Out:
# Bunga: 350000.00

# %% [markdown]
# ## **2. Konsep Bunga Majemuk / Bunga Berbunga**
#
# ---
#
# Setelah 1 tahun, Brian memiliki saldo akhir Rp10.350.000,-. Brian kemudian memutuskan untuk memperpanjang depositonya 1 tahun lagi, dengan suku bunga yang sama 3.5%.
#
# Dengan demikian, setelah 1 tahun lagi, Brian akan mendapatkan bunga dari deposito yang sudah berbunga:
#
# $$
# 0.035\times 10,350,000=362,250
# $$
#
# Sehingga saldo akhir Brian setelah tahun kedua adalah $10,350,000+362,250=10,712,250$.
#
# Konsep bunga berbunga ini juga dikenal sebagai _bunga majemuk (compound interest)_.
#
# Sebagai contoh, jika dihitung dari tahun pertama, saldo akhir Brian di tahun kedua adalah
#
# $$
# (1+0.035)^2 \times 10,000,000 = 10,712,250
# $$
#
# Di Python, operasi pangkat 2 ditulis dengan dua tanda bintang `**`, contohnya: `(1+0.035)**2`

# %% [markdown]
# ### **Rumus Saldo Akhir**
# Secara umum, rumus dari saldo akhir setelah $n$ periode, dimana setiap periodenya kita mendapat suku bunga $r$ adalah
#
# $$
# \text{Saldo akhir} = \text{Saldo awal} \times (1+r)^n
# $$

# %% [markdown]
# ### **Latihan 2.1 | Variabel**
#
# Hitung saldo akhir Brian setelah 2 tahun dengan Rumus Saldo Akhir, lalu masukkan hasilnya ke variabel baru `saldo_akhir_2thn`.

# %%
saldo_akhir = saldo_awal * (1+0.035)**2
print(saldo_akhir)
round(saldo_akhir,2)
# Out:
# 10712249.999999998
# 10712250.0

# %% [markdown]
# ### **Latihan 2.2 | Variabel, Debugging**
#
# Brian ingin menghitung saldo akhir apabila mendepositokan Rp10.000.000 di bank lain dengan suku bunga 4,5% per tahun selama 10 tahun. Ia membuat kode Python berikut.
#
#
# ```{python}
# # Kode buatan Brian
# periode = 10
# saldo_awal = 10000000
# suku_bunga = 0,045
# saldo_akhir_10thn = saldo_awal * (1+suku_bunga)**2
# print(saldo_akhir_10thn)
# ```
#
# Apakah kode buatan Brian benar? Jika tidak, perbaiki kode buatan Brian (_hint_: Saldo akhir Brian, `saldo_akhir_10thn`, seharusnya sekitar Rp15,5 juta).

# %%
# Kode buatan Brian
periode = 10
saldo_awal = 10000000
suku_bunga = 0.045
saldo_akhir_10thn = saldo_awal * (1+suku_bunga)**2
print(saldo_akhir_10thn)
round(saldo_akhir_10thn)
# Out:
# 10920249.999999998
# 10920250

# %% [markdown]
# ## **3. Pajak Penghasilan Atas Bunga Deposito**
#
# ---
#
# Brian adalah WNI dan wajib pajak di Indonesia. Menurut laman [Direktorat Jenderal Pajak](https://www.pajak.go.id/id/pph-pasal-4-ayat-2), bunga deposito yang memiliki saldo awal di atas Rp7.500.000,- akan dikenakan pajak penghasilan (PPh) pasal 4 ayat 2 sebesar 20% setiap tahunnya.
#
# Kembali ke contoh Brian di paling atas, apabila Brian mendepositokan Rp10.000.000,- selama 1 tahun dengan suku bunga tahunan 3,5%, maka Brian terkena PPh dengan tarif 20% (karena saldo awalnya di atas Rp7.500.000,-).
#
# Dengan demikian, sebetulnya Brian akan mendapatkan bunga kotor sebesar Rp350.000, dihitung dengan perhitungan bunga sederhana berikut
#
# $$0.035×10,000,000=350,000$$
#
# Kemudian bunga ini dipotong pajak 20% setiap tahunnya, sehingga bunga bersih yang diterima Brian adalah
#
# $$(1-20\%)\times 350,000= 280,000$$
#
# Dan saldo akhir Brian di akhir tahun akan menjadi Rp10.280.000,- setelah dipotong pajak.
#
# Sebaliknya, apabila Brian hanya mendepositokan uang sebesar Rp5.000.000,- (kurang dari Rp7,5 juta), maka ia tidak akan terkena PPh (atau dengan kata lain, tarif pajaknya 0%).

# %% [markdown]
# ### **Rumus Saldo Akhir Setelah Pajak (1 periode)**
# Secara umum, rumus dari saldo akhir setelah 1 periode, dimana setiap periodenya kita mendapat suku bunga $r$ dan tarif pajak $t$ adalah
#
# $$
# \text{Saldo akhir} = \text{Saldo awal} \times (1+(1-t)\times r)
# $$

# %% [markdown]
# ### **Latihan 3.1 | IF-ELSE**
#
# Buat sebuah kode Python yang memeriksa nilai variabel `saldo_awal`:
# - Jika `saldo_awal < 7500000` maka buat variabel `tarif_pajak` dengan nilai 0
# - Jika `saldo_awal >= 7500000`, maka buat variabel `tarif_pajak` dengan nilai 0.2
#
# Kemudian, `print` nilai `saldo_awal` dan `tarif_pajak`.

# %%
saldo_akhir = saldo_awal * (1+(1-0.2)*0.035)
print (saldo_akhir)
# Out:
# 10280000.0

# %%
saldo_awal = 10000000  # Ganti nilai ini sesuai kebutuhan

if saldo_awal < 7500000:
    tarif_pajak = 0
else:
    tarif_pajak = 0.2

print("Saldo Awal:", saldo_awal)
print("Tarif Pajak:", tarif_pajak)
# Out:
# Saldo Awal: 10000000
# Tarif Pajak: 0.2

# %% [markdown]
# ### **Latihan 3.2 | IF-ELSE**
#
# Ubah nilai `saldo_awal` menjadi Rp5.000.000.
#
# Buat sebuah kode Python yang memeriksa nilai variabel `saldo_awal`:
# - Jika `saldo_awal < 7500000` maka buat variabel `tarif_pajak` dengan nilai 0
# - Jika `saldo_awal >= 7500000`, maka buat variabel `tarif_pajak` dengan nilai 0.2
#
# Kemudian, `print` nilai `saldo_awal` dan `tarif_pajak`.

# %%
saldo_awal = 5000000  # Ganti nilai sesuai kebutuhan

if saldo_awal < 7500000:
    tarif_pajak = 0
else:
    tarif_pajak = 0.2

print("Saldo Awal:", saldo_awal)
print("Tarif Pajak:", tarif_pajak)
# Out:
# Saldo Awal: 5000000
# Tarif Pajak: 0

# %% [markdown]
# ### **Latihan 3.3 | Gabungkan IF-ELSE & Variabel**
#
# Brian sekarang memiliki rencana untuk menabung deposito sebagai berikut:
# - Saldo awal Rp7.500.000,-
# - Suku bunga: 3,5% per tahun
# - Deposito selama 1 tahun
#
# Buatlah kode Python untuk menentukan:
# - tarif pajak yang dikenakan kepada Brian
# - saldo akhir deposito Brian setelah 1 tahun, sebelum dikurangi pajak (seakan-akan tarif pajaknya 0)
# - saldo akhir deposito Brian setelah 1 tahun, sesudah dikurangi pajak
#
# Jangan lupa `print` tarif pajak, saldo sebelum pajak, dan saldo sesudah pajak.
#
# (Hint: Gunakan Rumus Saldo Akhir Setelah Pajak (1 Periode))

# %%
saldo_awal = 7500000
suku_bunga = 0.035
tarif_pajak = 0

if saldo_awal < 7500000:
    tarif_pajak = 0
else:
    tarif_pajak = 0.2

saldo_sebelum_pajak = saldo_awal + (saldo_awal * suku_bunga)
saldo_sesudah_pajak = saldo_sebelum_pajak - (saldo_sebelum_pajak * tarif_pajak)

print("Tarif Pajak:", tarif_pajak)
print("Saldo Sebelum Pajak:", saldo_sebelum_pajak)
print("Saldo Sesudah Pajak:", saldo_sesudah_pajak)
# Out:
# Tarif Pajak: 0.2
# Saldo Sebelum Pajak: 7762500.0
# Saldo Sesudah Pajak: 6210000.0

# %% [markdown]
# ## **4. Saldo Akhir Setelah Pajak Dengan Bunga Majemuk**
#
# ---
#
# Setelah adanya pajak, perhitungan saldo akhir pada bunga majemuk menjadi sedikit lebih rumit, dan harus dilakukan setiap tahunnya dengan rumus 1 periode. Hal ini karena tarif pajak yang berlaku mungkin berubah dari tahun ke tahun.
#
# Sebagai contoh di tabel di bawah ini, deposito dengan saldo awal Rp7juta dan suku bunga 10% pada tahun pertama tidak kena pajak, namun di tahun kedua terkena pajak 20%. Hal ini karena saldo awal di tahun kedua bernilai di atas Rp7,5juta.
#
# Di Python, kita bisa melakukan perhitungan berulang seperti ini dengan menggunakan `for` atau `while`.
#
# Lihat ke Google Sheet berikut: https://docs.google.com/spreadsheets/d/1wUolmZEeLfNwQRaSrD3m-q7xnR7gmKg_YU27LJujbV0/edit?usp=sharing

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Secara umum, pengulangan yang dilakukan mengikuti logika berikut:
#
#
# ```
# Untuk setiap tahun:
#    1. Tentukan saldo awal di tahun tersebut
#    2. Tentukan tarif pajak yang berlaku di tahun tersebut
#    3. Hitung saldo akhir di tahun tersebut dengan Rumus Saldo Akhir Setelah Pajak
#    4. Tentukan saldo awal untuk tahun berikutnya
# ```

# %% [markdown]
# ### **Latihan 4.1 | FOR loop**
#
# Brian membuat kode Python untuk menghitung saldo akhir depositonya setelah 5 tahun. Saldo awal deposito Brian adalah Rp7.000.000 dengan suku bunga 10%/tahun (sama dengan tabel di atas).
#
#
# ```python
# # Kode buatan Brian (saldo + pajak)
# periode = 5
# saldo_awal = 7000000
# suku_bunga = 0.1
#
# # Kondisi tahun pertama
# saldo_awal_tahun = saldo_awal
# saldo_akhir = 0
# tarif_pajak = 0
#
# # Untuk setiap tahun:
# for tahun in range(periode):
#   # 1. Tentukan tarif pajak yang berlaku di tahun tersebut
#   if saldo_awal_tahun < 7500000:
#     tarif_pajak = 0
#   elif saldo_awal_tahun >= 7500000:
#     tarif_pajak = 0.2
#
#   # 2. Hitung saldo akhir di tahun tersebut dengan Rumus Saldo Akhir Setelah Pajak
#   saldo_akhir = saldo_awal_tahun * (1 + (1-tarif_pajak)*suku_bunga)
#
#   # 3. Tentukan saldo awal untuk tahun berikutnya
#   saldo_awal_tahun = saldo_akhir
#
# print(f'Saldo akhir sesudah pajak : {saldo_akhir:,.0f}')
#
# ```
#
# Apakah kode buatan Brian benar? Jika tidak, perbaiki kode buatan Brian (hint: Saldo akhir Brian, `saldo_akhir`, seharusnya sekitar Rp10.475.765)

# %%
# Kode buatan Brian (saldo + pajak)
periode = 5
saldo_awal = 7000000
suku_bunga = 0.1

# Kondisi tahun pertama
saldo_awal_tahun = saldo_awal
saldo_akhir = 0
tarif_pajak = 0

# Untuk setiap tahun:
for tahun in range(periode):
  # 1. Tentukan tarif pajak yang berlaku di tahun tersebut
  if saldo_awal_tahun < 7500000:
    tarif_pajak = 0
  elif saldo_awal_tahun >= 7500000:
    tarif_pajak = 0.2

  # 2. Hitung saldo akhir di tahun tersebut dengan Rumus Saldo Akhir Setelah Pajak
  saldo_akhir = saldo_awal_tahun * (1 + (1-tarif_pajak)*suku_bunga)

  # 3. Tentukan saldo awal untuk tahun berikutnya
  saldo_awal_tahun = saldo_akhir

print(f'Saldo akhir sesudah pajak : {saldo_akhir:,.0f}')
# Out:
# Saldo akhir sesudah pajak : 10,475,765

# %% [markdown]
# ### **Latihan 4.2 | FOR loop**
#
# Misalkan Brian mendepositokan uang Rp5.500.000 selama 20 tahun dengan suku bunga 3.5% per tahun. Berapa saldo deposito Brian setelah 20 tahun? Mulai tahun keberapakah tarif pajak 20% berlaku untuk deposito Brian?
#
# (_Hint_: Salah satu cara untuk menyelesaikan masalah ini adalah dengan menambahkan `print(tarif_pajak)` di dalam `for` loop untuk melihat nilai `tarif_pajak` setiap tahunnya)

# %%
saldo_awal = 5500000
suku_bunga = 0.035
tarif_pajak = 0
periode = 20
saldo_depo = saldo_awal

for  tahun in range(1,21):
    saldo_depo += saldo_depo * suku_bunga
    if tahun == 1:
        print("Tahun ke-1, Tarif Pajak:", tarif_pajak)
    elif saldo_depo >= 7500000 and tarif_pajak != 0.2:
        tarif_pajak = 0.2
        print("Tahun ke-", tahun, "Tarif Pajak:", tarif_pajak)

print("Saldo Deposit Setelah 20 Tahun:", saldo_depo)
# Out:
# Tahun ke-1, Tarif Pajak: 0
# Tahun ke- 10 Tarif Pajak: 0.2
# Saldo Deposit Setelah 20 Tahun: 10943838.749062156

# %%
# kode brian deposit 20 tahun
periode = 20
saldo_awal = 5500000
suku_bunga = 0.035

# Kondisi tahun pertama
saldo_awal_tahun = saldo_awal
saldo_akhir = 0
tarif_pajak = 0

# loop tarif pajak
saldo_awal_tahun = saldo_awal

# Untuk setiap tahun:
for tahun in range(1,21):
  saldo_awal_tahun += saldo_awal_tahun * suku_bunga
# 1. Tentukan tarif pajak yang berlaku di tahun tersebut
  if tahun == 1 :
    tarif_pajak = 0
    print("Tahun ke-",tahun, "Tarif pajak:", tarif_pajak)
  elif saldo_awal_tahun >= 7500000 and tarif_pajak != 0.2:
    tarif_pajak = 0.2
    print("Tahun ke-", tahun, "Tarif Pajak:", tarif_pajak)
# 2. Hitung saldo akhir di tahun tersebut dengan Rumus Saldo Akhir Setelah Pajak
  saldo_akhir = saldo_awal_tahun * (1 + (1-tarif_pajak)*suku_bunga)

# 3. Tentukan saldo awal untuk tahun berikutnya
  saldo_awal_tahun = saldo_akhir

print(f'Saldo akhir sesudah pajak : {saldo_akhir:,.0f}')
print("Saldo Deposit Setelah 20 Tahun:", saldo_depo)
# Out:
# Tahun ke- 1 Tarif pajak: 0
# Tahun ke- 6 Tarif Pajak: 0.2
# Saldo akhir sesudah pajak : 19,668,360
# Saldo Deposit Setelah 20 Tahun: 10943838.749062156

# %%
# kode brian deposit 20 tahun
periode = 20
saldo_awal = 5500000
suku_bunga = 0.035

# Kondisi tahun pertama
saldo_awal_tahun = saldo_awal
saldo_akhir = 0
tarif_pajak = 0

# loop tarif pajak
saldo_awal_tahun = saldo_awal
for tahun in range(1, 21):
    saldo_awal_tahun += saldo_awal_tahun * suku_bunga
    if tahun == 1:
        print("Tahun ke-1, Tarif Pajak:", tarif_pajak)
    elif saldo_awal_tahun >= 7500000 and tarif_pajak != 0.2:
        tarif_pajak = 0.2
        print("Tahun ke-", tahun, "Tarif Pajak:", tarif_pajak)

# Untuk setiap tahun:
for tahun in range(periode):
# 1. Tentukan tarif pajak yang berlaku di tahun tersebut
  if saldo_awal_tahun < 7500000:
    tarif_pajak = 0
  elif saldo_awal_tahun >= 7500000:
    tarif_pajak = 0.2
# 2. Hitung saldo akhir di tahun tersebut dengan Rumus Saldo Akhir Setelah Pajak
  saldo_akhir = saldo_awal_tahun * (1 + (1-tarif_pajak)*suku_bunga)

# 3. Tentukan saldo awal untuk tahun berikutnya
  saldo_awal_tahun = saldo_akhir

print(f'Saldo akhir sesudah pajak : {saldo_akhir:,.0f}')
print("Saldo Deposit Setelah 20 Tahun:", saldo_depo)
round(saldo_depo)
# Out:
# Tahun ke-1, Tarif Pajak: 0
# Tahun ke- 10 Tarif Pajak: 0.2
# Saldo akhir sesudah pajak : 19,012,183
# Saldo Deposit Setelah 20 Tahun: 10943838.749062156
# 10943839
